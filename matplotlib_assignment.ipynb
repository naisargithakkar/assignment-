# %% [markdown]
# q1:
# Matplotlib is a Python library used for creating static, animated, and interactive visualizations in Python. It is used to create various types of plots using the Pyplot module. Some of the plots that can be plotted using the Pyplot module of Matplotlib are:
# Line Plot
# Histogram
# Scatter Plot
# 3D Plot
# Image Plot
# Contour Plot
# Polar Plot

# %% [markdown]
# Q2:A scatter plot is also called a scatter chart, scattergram, or scatter plot, XY graph. The scatter diagram graphs numerical data pairs, with one variable on each axis, show their relationship.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.title("this is my plot")
# Out:
# Text(0.5, 1.0, 'this is my plot')

# %% [markdown]
# q3:
#     With the subplot() function you can draw multiple plots in one figure

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,4,1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,4,2)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,4,3)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,4,4)
plt.plot(x,y)
plt.show()

# %% [markdown]
# #q4:
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically. A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# q5:
#     A box plot is a type of chart that shows the distribution of numerical data and skewness .
#      It is a simple way to visualize the shape of our data. It makes comparing characteristics of data between categories very easy.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9f4f2ea860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9f4f2eada0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9f4f2ea5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9f4f2eb2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9f4f2eb580>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9f4ebac1c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9f4ebac700>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9f4ed7bee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9f4ebacb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9f4ebacdc0>],
#  'means': []}
